# %% [markdown]
# # **Feature II - Investor Profiling**
#
# Feature II: Recommendations for SMEs with several categories by modeling for
# multiclass classification.

# %% [markdown]
# ## **Data Load & Understanding**

# %%
# Importing Libraries
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import validation_curve
import joblib
import os

# %% [markdown]
# ### **Data Load**

# %%
# Connecting Google Drive and Google Colab
from google.colab import drive
drive.mount('/content/gdrive')

# Retrieving Dataset
dataset = '/content/gdrive/MyDrive/Credit Score Classification Dataset.csv'
df = pd.read_csv(dataset)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load Dataset
df
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 159   29  Female   27500  High School Diploma         Single
# 160   34    Male   47500   Associate's Degree         Single
# 161   39  Female   62500    Bachelor's Degree        Married
# 162   44    Male   87500      Master's Degree         Single
# 163   49  Female   77500            Doctorate        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 1                     2          Owned         High
# 2                     1          Owned         High
# 3                     0          Owned         High
# 4                     3          Owned         High
# ..                  ...            ...          ...
# 159                   0         Rented          Low
# 160                   0         Rented      Average
# 161                   2          Owned         High
# 162                   0          Owned         High
# 163                   1          Owned         High
#
# [164 rows x 8 columns]

# %% [markdown]
# ### **Data Understanding**

# %%
df.shape
# Out:
# (164, 8)

# %%
# Display Information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 164 non-null    int64
#  1   Gender              164 non-null    object
#  2   Income              164 non-null    int64
#  3   Education           164 non-null    object
#  4   Marital Status      164 non-null    object
#  5   Number of Children  164 non-null    int64
#  6   Home Ownership      164 non-null    object
#  7   Credit Score        164 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 10.4+ KB

# %% [markdown]
# View information from the dataset using the `info(`) function where output will be given in the form of a list of column names, information on the amount of non-null data in each column and the data type of each column. From the data above, it is known that the data consists of 8 columns with a total of 164 rows.

# %% [markdown]
# **Exploratory Descriptive Statistic:** Information about the descriptive statistics of the data set can be found using the `.describe()` function. The information obtained is a summary of the measure of central tendency and measure of spread from each column containing numerical values in the data set.

# %%
df.describe()
# Out:
#               Age         Income  Number of Children
# count  164.000000     164.000000          164.000000
# mean    37.975610   83765.243902            0.652439
# std      8.477289   32457.306728            0.883346
# min     25.000000   25000.000000            0.000000
# 25%     30.750000   57500.000000            0.000000
# 50%     37.000000   83750.000000            0.000000
# 75%     45.000000  105000.000000            1.000000
# max     53.000000  162500.000000            3.000000

# %% [markdown]
# ## **Data Pre-Processing**

# %% [markdown]
# ### **Data Cleaning**

# %%
# Finding Missing Data
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                0
# Education             0
# Marital Status        0
# Number of Children    0
# Home Ownership        0
# Credit Score          0
# dtype: int64

# %%
# Remove Missing Values
df.dropna(inplace=True)

# %%
# Check Null Values
df.isna().sum()
# Out:
# Age                   0
# Gender                0
# Income                0
# Education             0
# Marital Status        0
# Number of Children    0
# Home Ownership        0
# Credit Score          0
# dtype: int64

# %%
# Check for Duplicate Data
df.duplicated().sum()
# Out:
# 62

# %%
# Delete all duplicate data except the first data
df.drop_duplicates(keep = 'first', inplace = True)

# %%
# Check for Duplicate Data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# After checking and deleting missing and duplicate values, the previously existing data contained 62 duplicate rows, therefore the duplicate data had to be deleted. So the new data is in the following table.

# %%
df
# Out:
#      Age  Gender  Income            Education Marital Status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 130   31    Male   95000            Doctorate         Single
# 131   26  Female   55000    Bachelor's Degree        Married
# 132   32    Male   85000      Master's Degree         Single
# 133   29  Female   68000            Doctorate        Married
# 134   34    Male  105000    Bachelor's Degree        Married
#
#      Number of Children Home Ownership Credit Score
# 0                     0         Rented         High
# 1                     2          Owned         High
# 2                     1          Owned         High
# 3                     0          Owned         High
# 4                     3          Owned         High
# ..                  ...            ...          ...
# 130                   0         Rented         High
# 131                   1          Owned      Average
# 132                   0         Rented         High
# 133                   2          Owned      Average
# 134                   1         Rented         High
#
# [102 rows x 8 columns]

# %% [markdown]
# ### **Data Manipulation**

# %%
# Change column names
df.rename(columns={
    'Credit Score': 'Label', 'Marital Status':'marital_status', 'Number of Children':'number_of_children', 'Home Ownership':'home_ownership'
}, inplace=True)

# Returns a DataFrame after changing column names
df
# Out:
#      Age  Gender  Income            Education marital_status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 130   31    Male   95000            Doctorate         Single
# 131   26  Female   55000    Bachelor's Degree        Married
# 132   32    Male   85000      Master's Degree         Single
# 133   29  Female   68000            Doctorate        Married
# 134   34    Male  105000    Bachelor's Degree        Married
#
#      number_of_children home_ownership    Label
# 0                     0         Rented     High
# 1                     2          Owned     High
# 2                     1          Owned     High
# 3                     0          Owned     High
# 4                     3          Owned     High
# ..                  ...            ...      ...
# 130                   0         Rented     High
# 131                   1          Owned  Average
# 132                   0         Rented     High
# 133                   2          Owned  Average
# 134                   1         Rented     High
#
# [102 rows x 8 columns]

# %%
df.columns = map(str.lower, df.columns)

# %%
df
# Out:
#      age  gender  income            education marital_status  \
# 0     25  Female   50000    Bachelor's Degree         Single
# 1     30    Male  100000      Master's Degree        Married
# 2     35  Female   75000            Doctorate        Married
# 3     40    Male  125000  High School Diploma         Single
# 4     45  Female  100000    Bachelor's Degree        Married
# ..   ...     ...     ...                  ...            ...
# 130   31    Male   95000            Doctorate         Single
# 131   26  Female   55000    Bachelor's Degree        Married
# 132   32    Male   85000      Master's Degree         Single
# 133   29  Female   68000            Doctorate        Married
# 134   34    Male  105000    Bachelor's Degree        Married
#
#      number_of_children home_ownership    label
# 0                     0         Rented     High
# 1                     2          Owned     High
# 2                     1          Owned     High
# 3                     0          Owned     High
# 4                     3          Owned     High
# ..                  ...            ...      ...
# 130                   0         Rented     High
# 131                   1          Owned  Average
# 132                   0         Rented     High
# 133                   2          Owned  Average
# 134                   1         Rented     High
#
# [102 rows x 8 columns]

# %% [markdown]
# **Convert USD to IDR:** The data on income is data on a person's annual income in USD. To adjust to IDR, need to make a conversion. The conversion is carried out by multiplying the USD by the IDR based on the exchange rate of 1 USD = 15,504 IDR (data as of 4 December 2023).

# %%
# USD to IDR conversion rate
rate_usd_to_idr = 15504

# Function for conversion
def convert_to_idr(income_usd):
     return income_usd * rate_usd_to_idr

# Apply the conversion function to the 'Income' column
df['income'] = df['income'].apply(convert_to_idr)

# Returns the DataFrame after conversion
df
# Out:
#      age  gender      income            education marital_status  \
# 0     25  Female   775200000    Bachelor's Degree         Single
# 1     30    Male  1550400000      Master's Degree        Married
# 2     35  Female  1162800000            Doctorate        Married
# 3     40    Male  1938000000  High School Diploma         Single
# 4     45  Female  1550400000    Bachelor's Degree        Married
# ..   ...     ...         ...                  ...            ...
# 130   31    Male  1472880000            Doctorate         Single
# 131   26  Female   852720000    Bachelor's Degree        Married
# 132   32    Male  1317840000      Master's Degree         Single
# 133   29  Female  1054272000            Doctorate        Married
# 134   34    Male  1627920000    Bachelor's Degree        Married
#
#      number_of_children home_ownership    label
# 0                     0         Rented     High
# 1                     2          Owned     High
# 2                     1          Owned     High
# 3                     0          Owned     High
# 4                     3          Owned     High
# ..                  ...            ...      ...
# 130                   0         Rented     High
# 131                   1          Owned  Average
# 132                   0         Rented     High
# 133                   2          Owned  Average
# 134                   1         Rented     High
#
# [102 rows x 8 columns]

# %% [markdown]
# **Adjustment of US GDP with ID GDP:** Then the income resulting from the conversion is adjusted to Indonesia's GDP, which is the United States' GDP (divided by 16). This is because there is a gap between the GDP of the United States which is 77,469 USD and the GDP of Indonesia which is 4,798 USD, which means that the GDP of the United States can be said to be around 16 times larger than the GDP of Indonesia. Because this model will later be used in Indonesia, adjustments need to be made to the existing income of Indonesian society.
#
# Data taken from https://countryeconomy.com/countries/compare/indonesia/usa for GDP in 2022.

# %%
# Divide the converted 'Income' by 16
df['income']/=16
df
# Out:
#      age  gender       income            education marital_status  \
# 0     25  Female   48450000.0    Bachelor's Degree         Single
# 1     30    Male   96900000.0      Master's Degree        Married
# 2     35  Female   72675000.0            Doctorate        Married
# 3     40    Male  121125000.0  High School Diploma         Single
# 4     45  Female   96900000.0    Bachelor's Degree        Married
# ..   ...     ...          ...                  ...            ...
# 130   31    Male   92055000.0            Doctorate         Single
# 131   26  Female   53295000.0    Bachelor's Degree        Married
# 132   32    Male   82365000.0      Master's Degree         Single
# 133   29  Female   65892000.0            Doctorate        Married
# 134   34    Male  101745000.0    Bachelor's Degree        Married
#
#      number_of_children home_ownership    label
# 0                     0         Rented     High
# 1                     2          Owned     High
# 2                     1          Owned     High
# 3                     0          Owned     High
# 4                     3          Owned     High
# ..                  ...            ...      ...
# 130                   0         Rented     High
# 131                   1          Owned  Average
# 132                   0         Rented     High
# 133                   2          Owned  Average
# 134                   1         Rented     High
#
# [102 rows x 8 columns]

# %% [markdown]
# **Convert Annual Income to Monthly Income:** To make it easier for users to enter data, the data which was originally annual income is converted to monthly income. In this case, Income is divided by 12 (the number of months in one year).

# %%
# Divide the converted 'Income' by 12
df['income']/=12
df
# Out:
#      age  gender      income            education marital_status  \
# 0     25  Female   4037500.0    Bachelor's Degree         Single
# 1     30    Male   8075000.0      Master's Degree        Married
# 2     35  Female   6056250.0            Doctorate        Married
# 3     40    Male  10093750.0  High School Diploma         Single
# 4     45  Female   8075000.0    Bachelor's Degree        Married
# ..   ...     ...         ...                  ...            ...
# 130   31    Male   7671250.0            Doctorate         Single
# 131   26  Female   4441250.0    Bachelor's Degree        Married
# 132   32    Male   6863750.0      Master's Degree         Single
# 133   29  Female   5491000.0            Doctorate        Married
# 134   34    Male   8478750.0    Bachelor's Degree        Married
#
#      number_of_children home_ownership    label
# 0                     0         Rented     High
# 1                     2          Owned     High
# 2                     1          Owned     High
# 3                     0          Owned     High
# 4                     3          Owned     High
# ..                  ...            ...      ...
# 130                   0         Rented     High
# 131                   1          Owned  Average
# 132                   0         Rented     High
# 133                   2          Owned  Average
# 134                   1         Rented     High
#
# [102 rows x 8 columns]

# %% [markdown]
# ### **Encoding**

# %%
# Make dictionary for encoding
gender_encoding = {'Male': 0, 'Female': 1}
education_encoding = {'High School Diploma': 0, "Associate's Degree": 1, "Bachelor's Degree": 2, "Master's Degree": 3, "Doctorate": 4}
marital_encoding = {'Single': 0, 'Married': 1}
home_encoding = {'Rented': 0, 'Owned': 1}
label_encoding = {'Low': 0, 'Average': 1, 'High' : 2}

# Doing label encoding using map method
df['gender'] = df['gender'].map(gender_encoding)
df['education'] = df['education'].map(education_encoding)
df['marital_status'] = df['marital_status'].map(marital_encoding)
df['home_ownership'] = df['home_ownership'].map(home_encoding)
df['label'] = df['label'].map(label_encoding)

# %%
df
# Out:
#      age  gender      income  education  marital_status  number_of_children  \
# 0     25       1   4037500.0          2               0                   0
# 1     30       0   8075000.0          3               1                   2
# 2     35       1   6056250.0          4               1                   1
# 3     40       0  10093750.0          0               0                   0
# 4     45       1   8075000.0          2               1                   3
# ..   ...     ...         ...        ...             ...                 ...
# 130   31       0   7671250.0          4               0                   0
# 131   26       1   4441250.0          2               1                   1
# 132   32       0   6863750.0          3               0                   0
# 133   29       1   5491000.0          4               1                   2
# 134   34       0   8478750.0          2               1                   1
#
#      home_ownership  label
# 0                 0      2
# 1                 1      2
# 2                 1      2
# 3                 1      2
# 4                 1      2
# ..              ...    ...
# 130               0      2
# 131               1      1
# 132               0      2
# 133               1      1
# 134               0      2
#
# [102 rows x 8 columns]

# %% [markdown]
# ### **Handling Imbalance Data (SMOTE)**

# %%
# Counting Stunting Case for each case
df['label'].value_counts()
# Out:
# 2    75
# 1    21
# 0     6
# Name: label, dtype: int64

# %%
df
# Out:
#      age  gender      income  education  marital_status  number_of_children  \
# 0     25       1   4037500.0          2               0                   0
# 1     30       0   8075000.0          3               1                   2
# 2     35       1   6056250.0          4               1                   1
# 3     40       0  10093750.0          0               0                   0
# 4     45       1   8075000.0          2               1                   3
# ..   ...     ...         ...        ...             ...                 ...
# 130   31       0   7671250.0          4               0                   0
# 131   26       1   4441250.0          2               1                   1
# 132   32       0   6863750.0          3               0                   0
# 133   29       1   5491000.0          4               1                   2
# 134   34       0   8478750.0          2               1                   1
#
#      home_ownership  label
# 0                 0      2
# 1                 1      2
# 2                 1      2
# 3                 1      2
# 4                 1      2
# ..              ...    ...
# 130               0      2
# 131               1      1
# 132               0      2
# 133               1      1
# 134               0      2
#
# [102 rows x 8 columns]

# %%
# Counts the number of each label
label_counts = df['label'].value_counts()

# Sort labels based on their number from largest to smallest
label_counts = label_counts.sort_values(ascending=False)

# Create a pie chart
plt.figure(figsize=(5, 5))
label_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')

# Add a title
plt.title('Distribution of Labels')

# Display graphics
plt.show()

# %% [markdown]
# Based on the pie chart above, it can be seen that 73.5% of the data in the `status` column is labeled **High (2)**, while the remaining 20.6% is labeled **Average (1)** and 5.9% is labeled **Low (0)**. So it can be concluded that the data does not have balanced proportions (imbalanced data) so it is necessary to handle the data.

# %%
# Separating the Feature and Labels
X = df[['age', 'gender', 'income', 'education', 'marital_status',	'number_of_children', 'home_ownership']]
y = df["label"]

smote = SMOTE(random_state=13)

# Fit predictor and target variable
X_smote, y_smote = smote.fit_resample(X, y)

print('Original dataset shape', y.value_counts())
print(' ')
print('Resample dataset shape', y_smote.value_counts())
# Out:
# Original dataset shape 2    75
# 1    21
# 0     6
# Name: label, dtype: int64
#
# Resample dataset shape 2    75
# 1    75
# 0    75
# Name: label, dtype: int64

# %%
X
# Out:
#      age  gender      income  education  marital_status  number_of_children  \
# 0     25       1   4037500.0          2               0                   0
# 1     30       0   8075000.0          3               1                   2
# 2     35       1   6056250.0          4               1                   1
# 3     40       0  10093750.0          0               0                   0
# 4     45       1   8075000.0          2               1                   3
# ..   ...     ...         ...        ...             ...                 ...
# 130   31       0   7671250.0          4               0                   0
# 131   26       1   4441250.0          2               1                   1
# 132   32       0   6863750.0          3               0                   0
# 133   29       1   5491000.0          4               1                   2
# 134   34       0   8478750.0          2               1                   1
#
#      home_ownership
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 130               0
# 131               1
# 132               0
# 133               1
# 134               0
#
# [102 rows x 7 columns]

# %%
X_smote
# Out:
#      age  gender        income  education  marital_status  number_of_children  \
# 0     25       1  4.037500e+06          2               0                   0
# 1     30       0  8.075000e+06          3               1                   2
# 2     35       1  6.056250e+06          4               1                   1
# 3     40       0  1.009375e+07          0               0                   0
# 4     45       1  8.075000e+06          2               1                   3
# ..   ...     ...           ...        ...             ...                 ...
# 220   31       0  4.754318e+06          1               0                   0
# 221   30       0  5.443448e+06          2               0                   0
# 222   31       0  5.546341e+06          2               0                   0
# 223   31       0  4.891153e+06          2               0                   0
# 224   31       0  3.909928e+06          1               0                   0
#
#      home_ownership
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 220               0
# 221               0
# 222               0
# 223               0
# 224               0
#
# [225 rows x 7 columns]

# %%
y_smote
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 220    1
# 221    1
# 222    1
# 223    1
# 224    1
# Name: label, Length: 225, dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %%
# Counts the number of each label
label_counts = y_smote.value_counts()

# Sort labels based on their number from largest to smallest
label_counts = label_counts.sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(6, 3))
label_counts.plot(kind='bar')

# Add x-axis (label) and y-axis (number) labels
plt.xlabel('Label')
plt.ylabel('Count')

# Add text with respective amounts to each bar
for i, v in enumerate(label_counts):
    plt.text(i, v, str(v), ha='center', va='bottom', fontsize=10)

# Display graphics
plt.tight_layout()  # To arrange the layout so that it does not overlap
plt.show()

# %%
# Counts the number of each label
label_counts = y_smote.value_counts()

# Sort labels based on their number from largest to smallest
label_counts = label_counts.sort_values(ascending=False)

# Create a pie chart
plt.figure(figsize=(5, 5))
label_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')

# Add a title
plt.title('Distribution of Labels')

# Display graphics
plt.show()

# %% [markdown]
# After handling data imbalance using SMOTE, based on the bar and pie charts above, it can be seen that each label has the same and balanced proportion, namely 33.33% or 75 for each label.

# %%
def diagnostic_plots(df,variable):
    plt.figure(figsize=(16,4))

    #Histogram
    plt.subplot(1,2,1)
    sns.histplot(df[variable],bins=30)
    plt.title('Histogram')

    # Boxplot
    plt.subplot(1,2,2)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

diagnostic_plots(X_smote, 'age')
diagnostic_plots(X_smote, 'gender')
diagnostic_plots(X_smote, 'income')
diagnostic_plots(X_smote, 'education')
diagnostic_plots(X_smote, 'marital_status')
diagnostic_plots(X_smote, 'number_of_children')
diagnostic_plots(X_smote, 'home_ownership')

# %%
print('Skewness of Age:', X_smote['age'].skew())
print('Skewness of Gender:', X_smote['gender'].skew())
print('Skewness of Income:', X_smote['income'].skew())
print('Skewness of Education:', X_smote['education'].skew())
print('Skewness of Marital Status:', X_smote['marital_status'].skew())
print('Skewness of Number of Children:', X_smote['number_of_children'].skew())
print('Skewness of Home Ownership:', X_smote['home_ownership'].skew())
# Out:
# Skewness of Age: 1.147560130845823
# Skewness of Gender: -0.31706256648363484
# Skewness of Income: 0.9873552686630469
# Skewness of Education: 0.6195885433306242
# Skewness of Marital Status: 1.1149738216739866
# Skewness of Number of Children: 2.2093881210170156
# Skewness of Home Ownership: 0.7550127269704379

# %%
# Combine X_smote and y_smote into a single DataFrame
df_smote = pd.concat([X_smote, y_smote], axis=1)

# Plot the heatmap
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df_smote.corr(), annot=True, cmap='Blues', fmt=".2f", ax=ax)

# Show the plot
plt.show()

# %%
df
# Out:
#      age  gender      income  education  marital_status  number_of_children  \
# 0     25       1   4037500.0          2               0                   0
# 1     30       0   8075000.0          3               1                   2
# 2     35       1   6056250.0          4               1                   1
# 3     40       0  10093750.0          0               0                   0
# 4     45       1   8075000.0          2               1                   3
# ..   ...     ...         ...        ...             ...                 ...
# 130   31       0   7671250.0          4               0                   0
# 131   26       1   4441250.0          2               1                   1
# 132   32       0   6863750.0          3               0                   0
# 133   29       1   5491000.0          4               1                   2
# 134   34       0   8478750.0          2               1                   1
#
#      home_ownership  label
# 0                 0      2
# 1                 1      2
# 2                 1      2
# 3                 1      2
# 4                 1      2
# ..              ...    ...
# 130               0      2
# 131               1      1
# 132               0      2
# 133               1      1
# 134               0      2
#
# [102 rows x 8 columns]

# %% [markdown]
# ## **Modelling & Evaluation**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
normalized_data = scaler.fit_transform(X_smote)

# Convert the normalized data back to a DataFrame
normalized_df = pd.DataFrame(normalized_data, columns=X_smote.columns)

# Save the normalization model using joblib
joblib.dump(scaler, 'normalization_model.joblib')

# Print the normalized DataFrame
print(normalized_df)
# Out:
#           age    gender    income  education  marital_status  \
# 0   -1.025356  0.854850 -0.388036   0.517522       -0.589326
# 1   -0.400139 -1.169795  1.114021   1.263948        1.696853
# 2    0.225078  0.854850  0.362993   2.010373        1.696853
# 3    0.850295 -1.169795  1.865049  -0.975330       -0.589326
# 4    1.475512  0.854850  1.114021   0.517522        1.696853
# ..        ...       ...       ...        ...             ...
# 220 -0.275096 -1.169795 -0.121360  -0.228904       -0.589326
# 221 -0.400139 -1.169795  0.135014   0.517522       -0.589326
# 222 -0.275096 -1.169795  0.173293   0.517522       -0.589326
# 223 -0.275096 -1.169795 -0.070454   0.517522       -0.589326
# 224 -0.275096 -1.169795 -0.435496  -0.228904       -0.589326
#
#      number_of_children  home_ownership
# 0             -0.458456        -0.69301
# 1              2.447250         1.44298
# 2              0.994397         1.44298
# 3             -0.458456         1.44298
# 4              3.900103         1.44298
# ..                  ...             ...
# 220           -0.458456        -0.69301
# 221           -0.458456        -0.69301
# 222           -0.458456        -0.69301
# 223           -0.458456        -0.69301
# 224           -0.458456        -0.69301
#
# [225 rows x 7 columns]

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(normalized_df, y_smote, test_size=0.2, random_state=42)

# %% [markdown]
# ### **MLP (Multi Layer Perceptron) Modelling**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Standardize the data (optional, but recommended for MLP)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a Sequential model for tabular data (MLP)
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 class output

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model on training data
history = model.fit(X_train_scaled, y_train, epochs=100, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 39ms/step - loss: 0.8889 - accuracy: 0.7278 - val_loss: 0.7920 - val_accuracy: 0.8667
# Epoch 2/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6381 - accuracy: 0.9167 - val_loss: 0.6144 - val_accuracy: 0.9556
# Epoch 3/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4832 - accuracy: 0.9444 - val_loss: 0.4777 - val_accuracy: 0.9556
# Epoch 4/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3765 - accuracy: 0.9389 - val_loss: 0.3687 - val_accuracy: 0.9556
# Epoch 5/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2993 - accuracy: 0.9444 - val_loss: 0.2891 - val_accuracy: 0.9556
# Epoch 6/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.2487 - accuracy: 0.9444 - val_loss: 0.2358 - val_accuracy: 0.9556
# Epoch 7/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2102 - accuracy: 0.9444 - val_loss: 0.2008 - val_accuracy: 0.9556
# Epoch 8/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1837 - accuracy: 0.9444 - val_loss: 0.1754 - val_accuracy: 0.9556
# Epoch 9/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1633 - accuracy: 0.9444 - val_loss: 0.1560 - val_accuracy: 0.9556
# Epoch 10/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1489 - accuracy: 0.9444 - val_loss: 0.1437 - val_accuracy: 0.9556
# Epoch 11/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1343 - accuracy: 0.9444 - val_loss: 0.1358 - val_accuracy: 0.9556
# Epoch 12/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1241 - accuracy: 0.9500 - val_loss: 0.1284 - val_accuracy: 0.9556
# Epoch 13/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1146 - accuracy: 0.9500 - val_loss: 0.1227 - val_accuracy: 0.9556
# Epoch 14/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1073 - accuracy: 0.9500 - val_loss: 0.1171 - val_accuracy: 0.9556
# Epoch 15/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1007 - accuracy: 0.9556 - val_loss: 0.1131 - val_accuracy: 0.9556
# Epoch 16/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0947 - accuracy: 0.9556 - val_loss: 0.1084 - val_accuracy: 0.9556
# Epoch 17/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0895 - accuracy: 0.9611 - val_loss: 0.1045 - val_accuracy: 0.9778
# Epoch 18/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0857 - accuracy: 0.9611 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 19/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0815 - accuracy: 0.9722 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 20/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0778 - accuracy: 0.9778 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 21/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0753 - accuracy: 0.9722 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 22/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0718 - accuracy: 0.9833 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 23/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0694 - accuracy: 0.9944 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 24/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0667 - accuracy: 0.9944 - val_loss: 0.0830 - val_accuracy: 1.0000
# Epoch 25/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0637 - accuracy: 0.9944 - val_loss: 0.0805 - val_accuracy: 1.0000
# Epoch 26/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0618 - accuracy: 0.9944 - val_loss: 0.0794 - val_accuracy: 1.0000
# Epoch 27/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0600 - accuracy: 0.9944 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 28/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0578 - accuracy: 0.9944 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 29/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0563 - accuracy: 0.9944 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 30/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0544 - accuracy: 0.9944 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 31/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0526 - accuracy: 0.9944 - val_loss: 0.0674 - val_accuracy: 1.0000
# Epoch 32/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.9944 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 33/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0492 - accuracy: 0.9944 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 34/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0483 - accuracy: 0.9944 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 35/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0477 - accuracy: 0.9944 - val_loss: 0.0632 - val_accuracy: 1.0000
# Epoch 36/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0455 - accuracy: 0.9944 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 37/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0448 - accuracy: 0.9944 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 38/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0434 - accuracy: 0.9944 - val_loss: 0.0557 - val_accuracy: 1.0000
# Epoch 39/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0423 - accuracy: 0.9944 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 40/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0415 - accuracy: 0.9944 - val_loss: 0.0529 - val_accuracy: 1.0000
# Epoch 41/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0404 - accuracy: 0.9944 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 42/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0397 - accuracy: 0.9944 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 43/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0388 - accuracy: 0.9944 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 44/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0382 - accuracy: 0.9944 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 45/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0375 - accuracy: 0.9944 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 46/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0368 - accuracy: 0.9944 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 47/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0358 - accuracy: 0.9944 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 48/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0354 - accuracy: 0.9944 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 49/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0342 - accuracy: 0.9944 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 50/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0336 - accuracy: 0.9944 - val_loss: 0.0400 - val_accuracy: 1.0000
# Epoch 51/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0328 - accuracy: 0.9944 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 52/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0323 - accuracy: 0.9944 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 53/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0320 - accuracy: 0.9944 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 54/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0310 - accuracy: 0.9944 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 55/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0311 - accuracy: 0.9944 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 56/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0307 - accuracy: 0.9944 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 57/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0297 - accuracy: 0.9944 - val_loss: 0.0327 - val_accuracy: 1.0000
# Epoch 58/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0293 - accuracy: 0.9944 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 59/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0289 - accuracy: 0.9944 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 60/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0285 - accuracy: 0.9944 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 61/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0281 - accuracy: 0.9944 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 62/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0274 - accuracy: 0.9944 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 63/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0270 - accuracy: 0.9944 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 64/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0272 - accuracy: 0.9944 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 65/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0262 - accuracy: 0.9944 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 66/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0260 - accuracy: 0.9944 - val_loss: 0.0272 - val_accuracy: 1.0000
# Epoch 67/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0261 - accuracy: 0.9944 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 68/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0260 - accuracy: 0.9944 - val_loss: 0.0264 - val_accuracy: 1.0000
# Epoch 69/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0250 - accuracy: 0.9944 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 70/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0247 - accuracy: 0.9944 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 71/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0248 - accuracy: 0.9944 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 72/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0240 - accuracy: 0.9944 - val_loss: 0.0234 - val_accuracy: 1.0000
# Epoch 73/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0240 - accuracy: 0.9944 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 74/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0238 - accuracy: 0.9944 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 75/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0233 - accuracy: 0.9944 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 76/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0235 - accuracy: 0.9944 - val_loss: 0.0233 - val_accuracy: 1.0000
# Epoch 77/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0228 - accuracy: 0.9944 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 78/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0228 - accuracy: 0.9944 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 79/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0226 - accuracy: 0.9944 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 80/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0220 - accuracy: 0.9944 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 81/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0220 - accuracy: 0.9944 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 82/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0218 - accuracy: 0.9944 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 83/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0214 - accuracy: 0.9944 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 84/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0214 - accuracy: 0.9944 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 85/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0207 - accuracy: 0.9944 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 86/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0210 - accuracy: 0.9944 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 87/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0211 - accuracy: 0.9944 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 88/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0201 - accuracy: 0.9944 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 89/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0201 - accuracy: 0.9944 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 90/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0207 - accuracy: 0.9944 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 92/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0186 - val_accuracy: 1.0000
# Epoch 93/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 95/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 96/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 97/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0196 - accuracy: 0.9944 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0186 - accuracy: 0.9944 - val_loss: 0.0168 - val_accuracy: 1.0000

# %%
np.set_printoptions(threshold=np.inf)

# %%
df
# Out:
#      age  gender      income  education  marital_status  number_of_children  \
# 0     25       1   4037500.0          2               0                   0
# 1     30       0   8075000.0          3               1                   2
# 2     35       1   6056250.0          4               1                   1
# 3     40       0  10093750.0          0               0                   0
# 4     45       1   8075000.0          2               1                   3
# ..   ...     ...         ...        ...             ...                 ...
# 130   31       0   7671250.0          4               0                   0
# 131   26       1   4441250.0          2               1                   1
# 132   32       0   6863750.0          3               0                   0
# 133   29       1   5491000.0          4               1                   2
# 134   34       0   8478750.0          2               1                   1
#
#      home_ownership  label
# 0                 0      2
# 1                 1      2
# 2                 1      2
# 3                 1      2
# 4                 1      2
# ..              ...    ...
# 130               0      2
# 131               1      1
# 132               0      2
# 133               1      1
# 134               0      2
#
# [102 rows x 8 columns]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               1024
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 9475 (37.01 KB)
# Trainable params: 9475 (37.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(np.array([[25,	1,	4037500.0,	2,	0,	0,	0]]))
# Out:
# 1/1 [==============================] - 0s 57ms/step
# array([[0., 0., 1.]], dtype=float32)

# %% [markdown]
# ### **Model Evaluation**

# %%
# Predict on the test data
y_probabilities = model.predict(X_test_scaled)

# Convert predicted probabilities to class labels
y_pred = y_probabilities.argmax(axis=-1)

# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
# Plot training and validation accuracy values
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot training and validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Model Evaluation
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[15  0  0]
#  [ 0 20  0]
#  [ 0  0 10]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        20
#            2       1.00      1.00      1.00        10
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ### **Model Predict**

# %% [markdown]
# ## **Save Model**

# %%
# Save model has build
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import drive
import os
from tensorflow.keras.models import save_model

# Save model to .h5
drive.mount('/content/drive')
os.makedirs('/content/drive/MyDrive/', exist_ok=True)

# Save the MLP model (.h5) to the Google Drive folder
model_filename = '/content/drive/MyDrive/bevest_feature2_model.h5'
model.save(model_filename)

print(f"Model saved successfully to {model_filename}")
# Out:
# Mounted at /content/drive
# Model saved successfully to /content/drive/MyDrive/bevest_feature2_model.h5
